# %% [markdown]
# basic EDA

# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0  \
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors
# 0               6.0            MANUAL  rear wheel drive              2.0  \
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe  \
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
data.size
# Out:
# 190624

# %%
data.shape
# Out:
# (11914, 16)

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors
# count  11914.000000  11845.00000      11884.000000     11908.000000  \
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.100000e+04
# 50%       26.000000     18.000000   1385.000000  2.999500e+04
# 75%       30.000000     22.000000   2009.000000  4.223125e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %%
data.describe(include='all')
# Out:
#              Make           Model          Year  Engine Fuel Type
# count       11914           11914  11914.000000             11911  \
# unique         48             915           NaN                10
# top     Chevrolet  Silverado 1500           NaN  regular unleaded
# freq         1123             156           NaN              7172
# mean          NaN             NaN   2010.384338               NaN
# std           NaN             NaN      7.579740               NaN
# min           NaN             NaN   1990.000000               NaN
# 25%           NaN             NaN   2007.000000               NaN
# 50%           NaN             NaN   2015.000000               NaN
# 75%           NaN             NaN   2016.000000               NaN
# max           NaN             NaN   2017.000000               NaN
#
#           Engine HP  Engine Cylinders Transmission Type      Driven_Wheels
# count   11845.00000      11884.000000             11914              11914  \
# unique          NaN               NaN                 5                  4
# top             NaN               NaN         AUTOMATIC  front wheel drive
# freq            NaN               NaN              8266               4787
# mean      249.38607          5.628829               NaN                NaN
# std       109.19187          1.780559               NaN                NaN
# min        55.00000          0.000000               NaN                NaN
# 25%       170.00000          4.000000               NaN                NaN
# 50%       227.00000          6.000000               NaN                NaN
# 75%       300.00000          6.000000               NaN                NaN
# max      1001.00000         16.000000               NaN                NaN
#
#         Number of Doors Market Category Vehicle Size Vehicle Style
# count      11908.000000            8172        11914         11914  \
# unique              NaN              71            3            16
# top                 NaN       Crossover      Compact         Sedan
# freq                NaN            1110         4764          3048
# mean           3.436093             NaN          NaN           NaN
# std            0.881315             NaN          NaN           NaN
# min            2.000000             NaN          NaN           NaN
# 25%            2.000000             NaN          NaN           NaN
# 50%            4.000000             NaN          NaN           NaN
# 75%            4.000000             NaN          NaN           NaN
# max            4.000000             NaN          NaN           NaN
#
#          highway MPG      city mpg    Popularity          MSRP
# count   11914.000000  11914.000000  11914.000000  1.191400e+04
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean       26.637485     19.733255   1554.911197  4.059474e+04
# std         8.863001      8.987798   1441.855347  6.010910e+04
# min        12.000000      7.000000      2.000000  2.000000e+03
# 25%        22.000000     16.000000    549.000000  2.100000e+04
# 50%        26.000000     18.000000   1385.000000  2.999500e+04
# 75%        30.000000     22.000000   2009.000000  4.223125e+04
# max       354.000000    137.000000   5657.000000  2.065902e+06

# %% [markdown]
# Getting know the individual fields

# %%
# getting know the make filed
data['Make'].unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %%
data['Make'].count()
# Out:
# 11914

# %%
data['Make'].value_counts()
# Out:
# Make
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# HUMMER             17
# Maybach            16
# Alfa Romeo          5
# McLaren             5
# Spyker              3
# Genesis             3
# Bugatti             3
# Name: count, dtype: int64

# %% [markdown]
# Exploring the data and altering the data type accordingly

# %%
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0  \
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors
# 0               6.0            MANUAL  rear wheel drive              2.0  \
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe  \
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
data['Engine HP'].dtype == 'O'
# Out:
# False

# %%
data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
for col in data.columns:
    print("dataType:", data[col].dtypes, end=' :')
    if data[col].dtype == 'O':
        print(data[col].nunique())
        print(data[col].unique())
    else:
        print("\n\n")

# %%
# by analysing the values belongs to object seems to be categorical converting
for col in data.columns:
    if data[col].dtype == 'O':
        data[col] = pd.Categorical(data[col])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  category
#  1   Model              11914 non-null  category
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  category
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  category
#  7   Driven_Wheels      11914 non-null  category
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   category
#  10  Vehicle Size       11914 non-null  category
#  11  Vehicle Style      11914 non-null  category
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: category(8), float64(3), int64(5)
# memory usage: 894.5 KB

# %%
# we can do a visualization part with matplotlib
import matplotlib.pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13348\2957938333.py in <module>
#       1 # vehicle style by year
# ----> 2 data.groupby('Year')['Year'].value_counts().plot(type='bar')
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     973                     data.columns = label_name
#     974
# --> 975         return plot_backend.plot(data, kind=kind, **kwargs)
#     976
#     977     __call__.__doc__ = __doc__
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     446         self._compute_plot_data()
#     447         self._setup_subplots()
# --> 448         self._make_plot()
#     449         self._add_table()
#     450         self._make_legend()
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1380             kwds["label"] = label
#    1381
# -> 1382             newlines = plotf(
#    1383                 ax,
#    1384                 x,
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1409             cls._initialize_stacker(ax, stacking_id, len(y))
#    1410         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1411         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1412         cls._update_stacker(ax, stacking_id, y)
#    1413         return lines
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\converter.py in wrapper(*args, **kwargs)
#      94     def wrapper(*args, **kwargs):
#      95         with pandas_converters():
# ---> 96             return func(*args, **kwargs)
#      97
#      98     return cast(F, wrapper)
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     883             # prevent style kwarg from going to errorbar, where it is unsupported
#     884             args = (x, y, style) if style is not None else (x, y)
# --> 885             return ax.plot(*args, **kwds)
#     886
#     887     def _get_custom_index_name(self):
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1660         """
#    1661         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663         for line in lines:
#    1664             self.add_line(line)
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     542             return list(result)
#     543         else:
# --> 544             return [l[0] for l in result]
#     545
#     546
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     542             return list(result)
#     543         else:
# --> 544             return [l[0] for l in result]
#     545
#     546
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     535             labels = [label] * n_datasets
#     536
# --> 537         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     538                               {**kwargs, 'label': label})
#     539                   for j, label in enumerate(labels))
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     349         default_dict = self._getdefaults(set(), kw)
#     350         self._setdefaults(default_dict, kw)
# --> 351         seg = mlines.Line2D(x, y, **kw)
#     352         return seg, kw
#     353
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     452                 "parameter will become keyword-only %(removal)s.",
#     453                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454         return func(*args, **kwargs)
#     455
#     456     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391         # update kwargs before updating data to give the caller a
#     392         # chance to init axes (and hence unit support)
# --> 393         self._internal_update(kwargs)
#     394         self._pickradius = pickradius
#     395         self.ind_offset = 0
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py in _internal_update(self, kwargs)
#    1184         The lack of prenormalization is to maintain backcompatibility.
#    1185         """
# -> 1186         return self._update_props(
#    1187             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1188             "{prop_name!r}")
#
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py in _update_props(self, props, errfmt)
#    1158                     func = getattr(self, f"set_{k}", None)
#    1159                     if not callable(func):
# -> 1160                         raise AttributeError(
#    1161                             errfmt.format(cls=type(self), prop_name=k))
#    1162                     ret.append(func(v))
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'type'
